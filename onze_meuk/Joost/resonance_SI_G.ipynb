# %%
from IPython.display import clear_output
import rebound
import matplotlib.pyplot as plt
import numpy as np

# %%
sim = rebound.Simulation()

AU = 1.496e11
sim.G = 6.6743e-11 # m^3 / kg s^2
sim.add(m=1.98847e30)
sim.add(m=1.89813e27,a=778.479e9)
#sim.add(m=0.0009547919099366768, x=4.700873257350307, y=-1.638871658756794, z=-0.09837100227914734, vx=0.1391574941369194, vy=0.4348006080824522, vz=-0.004917193679728236)
sim.move_to_com()
#sim.integrator = "mercurius"
sim.integrator = "whfast"
sim.dt = 60*60*24

# %%
fig, ax = rebound.OrbitPlot(sim)

# %%
sim.add(m=5000,a=2.502*AU, omega = 1.5*np.pi)

# %%
a_list = []
i_list = []
jup_list = []

for i in range(120*365*2):
    #sim.integrate(i*60*60*24)
    
    sim.step()
    a_list.append(sim.particles[2].a)
    jup_list.append(sim.particles[1].a)
    i_list.append(i)
    
    clear_output(wait=True)
    print(i/(365*120*2))


plt.plot(i_list,a_list)
plt.show()
# Out:
# 0.9999885844748858

# %%
print(sim.particles[2].a/AU)
# Out:
# 2.5031692601904534

# %%
print(0.40*AU)
# Out:
# 59840000000.0

# %%
plt.plot(i_list[:100],a_list[:100])
plt.show()

# %%
sim.status()
# Out:
# ---------------------------------
# REBOUND version:     	3.19.1
# REBOUND built on:    	Jan 14 2022 11:24:53
# Number of particles: 	3
# Selected integrator: 	mercurius
# Simulation time:     	3.1536000000000000e+09
# Current timestep:    	86400.000000
# ---------------------------------
# <rebound.particle.Particle object at 0x7f640813a7c0, m=1.98847e+30 x=655470941.5884382 y=-348596281.67396206 z=0.0 vx=5.849543358559231 vy=10.998986206646364 vz=0.0>
# <rebound.particle.Particle object at 0x7f640813adc0, m=1.89813e+27 x=-686667563981.5262 y=365187446708.25073 z=0.0 vx=-6127.947760266292 vy=-11522.474278542608 vz=0.0>
# <rebound.particle.Particle object at 0x7f640813a7c0, m=100.0 x=348762840630.8795 y=139040952189.82184 z=0.0 vx=-6967.358003396032 vy=17515.27112161016 vz=0.0>
# ---------------------------------
