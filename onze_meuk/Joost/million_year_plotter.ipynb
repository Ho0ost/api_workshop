# %%
from IPython.display import clear_output
import rebound
import matplotlib.pyplot as plt
import numpy as np
import random
import csv
import pandas as pd

# %%
#data= pd.read_csv("sim.csv")
data_final_a = pd.read_csv('data_base.csv', usecols= ['final a'])
data_final_e = pd.read_csv('data_base.csv', usecols= ['final ecc'])
data = pd.read_csv('data_base.csv')

data.plot.scatter(x="final a",y="final ecc",xlim=(2.3,2.7),ylim=(0,1),s=2)


#plt.plot(data_final_e[1:],data_final_a[1:])
#plt.show()
data_final_a.min()
# Out:
# final a   -48.875838
# dtype: float64

# %%
data.plot.hist("final a",xlim=(0,3))#,xlim=(2.3,2.7))
