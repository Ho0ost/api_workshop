# %%
from IPython.display import clear_output
import rebound
import matplotlib.pyplot as plt
import numpy as np
import random
import csv
import pandas as pd

# %%
#data= pd.read_csv("sim.csv")
data_final_a = pd.read_csv('data_base.csv', usecols= ['final a'])
data_final_e = pd.read_csv('data_base.csv', usecols= ['final ecc'])
data = pd.read_csv('data_base.csv')

data.plot.scatter(x="final a",y="final ecc",xlim=(2.3,2.7))


#plt.plot(data_final_e[1:],data_final_a[1:])
#plt.show()
data_final_a.min()
# Out:
# final a   -21.1386
# dtype: float64

# %%
data_final_a.plot.hist(xlim=(0,3))#,xlim=(2.3,2.7))
# Out:
# <AxesSubplot:ylabel='Frequency'>
