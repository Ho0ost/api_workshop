# %%
from IPython.display import clear_output
import rebound
import matplotlib.pyplot as plt
import numpy as np
import random
import csv
import pandas as pd

# %%
# wooeeper
a_start = 2.4976115451570733
e_start = 0.19619437087192476
omega_start = 2.346999995573862

# %%
sim = rebound.Simulation()

# add sun
sim.move_to_com()
sim.integrator = "whfast"
sim.dt = .1
simtime = 1e4 # 1 millione years

total_astroids = 1

starting_a = 0.
starting_e = 0.
final_a = 0.
final_e = 0.

mass = 1e-29
radius = a_start
omega = omega_start
ecc = e_start
    
# sun
sim.add(m=0.9999999999950272, x=-0.008669035216216899, y=0.0031140563797133693, z=0.00017700903203290386, vx=-0.00017842972567085554, vy=-0.0004942109647718484, vz=8.170411607613112e-06)
# jupiter
sim.add(m=0.0009547919099366768, x=4.717393707823112, y=-1.58629315260585, z=-0.0989587433278056, vx=0.13456873359546767, vy=0.4363713717691052, vz=-0.004821057409397645)
# mars
sim.add(m=3.2271560828978514e-07, x=-0.5195763051075928, y=-1.4079912951728626, z=-0.016864026009610615, vx=0.7953007114278168, vy=-0.2075756016137399, vz=-0.023844826829689417)
# add astroid
sim.add(m=mass,a=radius,omega=omega, e=ecc)

# %%
#first part
years = 400000
for i in range (int(years*(1/sim.dt))):
    sim.step()


# yeet part
years = 200000

# second part
#years = 350000
#yeart = 100000
# 400.000 oei oei
# 600.000 goners

a_list = []
time_list = []
e_list = []

save_rate = 1000

#skip shit
# for j in range (9722):
#     clear_output(wait=True)
#     print(j/(3917))
#     for i in range (int(years*(1/sim.dt)/save_rate)):
        
#         sim.step()

jupiter_distance_list = []
mars_distance_list = []

for j in range (save_rate):
    clear_output(wait=True)
    print(j/(save_rate))
    for i in range (int(years*(1/sim.dt)/save_rate)):
        
        sim.step()
        # second part
        a_list.append(sim.particles[3].a)
        e_list.append(sim.particles[3].e)
        time_list.append(i)
    
        jupiter_distance_list.append(np.sqrt((sim.particles[1].x-sim.particles[3].x)**2+(sim.particles[1].y-sim.particles[3].y)**2+(sim.particles[1].z-sim.particles[3].z)**2))
        mars_distance_list.append(np.sqrt((sim.particles[2].x-sim.particles[3].x)**2+(sim.particles[2].y-sim.particles[3].y)**2+(sim.particles[2].z-sim.particles[3].z)**2))

        
    #fig = rebound.OrbitPlot(sim)
    #plt.savefig('animate_save/plot_{}.png'.format(j+9722))
# Out:
# 0.492
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <module>
#      37 sim.step()
#      38 # second part
# ---> 39 a_list.append(sim.particles[3].a)
#      40 e_list.append(sim.particles[3].e)
#      41 time_list.append(i)
#
# File ~/.local/lib/python3.8/site-packages/rebound/particle.py:703, in Particle.a(self)
#     701 @property
#     702 def a(self):
# --> 703     return self.calculate_orbit().a
#
# File ~/.local/lib/python3.8/site-packages/rebound/particle.py:449, in Particle.calculate_orbit(self, primary, G)
#     447 err = c_int()
#     448 clibrebound.reb_tools_particle_to_orbit_err.restype = rebound.Orbit
# --> 449 o = clibrebound.reb_tools_particle_to_orbit_err(G, self, primary, byref(err))
#     451 if err.value == 1:
#     452     raise ValueError("Primary has no mass.")
#
# KeyboardInterrupt:

# %%
fig = rebound.OrbitPlot(sim)

# %%
plt.plot(time_list,a_list)
#plt.xlim([10,11])
#plt.ylim([0,5])
plt.show()

# %%
plt.scatter(a_list,e_list)
plt.xlim([0,4])
plt.show()

# %%
sim.status()
# Out:
# ---------------------------------
# REBOUND version:     	3.19.1
# REBOUND built on:    	Jan 14 2022 11:24:53
# Number of particles: 	4
# Selected integrator: 	whfast
# Simulation time:     	1.4000000007294030e+06
# Current timestep:    	0.100000
# ---------------------------------
# <rebound.particle.Particle object at 0x7fa9eb3efdc0, m=0.9999999999950272 x=-69.49610497900638 y=-108.58039120248452 z=4.9786656205361295 vx=-0.00020902248352560064 vy=0.0002882762760245945 vz=5.604790141475289e-06>
# <rebound.particle.Particle object at 0x7fa9eb3efac0, m=0.0009547919099366768 x=-74.51047706496061 y=-110.71612422618693 z=5.099698696589118 vx=0.1666399211409624 vy=-0.38310527292361085 vz=-0.002138134895034453>
# <rebound.particle.Particle object at 0x7fa9eb3efdc0, m=3.2271560828978514e-07 x=-70.13755815299163 y=-109.97032911924431 z=5.03730476790468 vx=0.7068239801203904 vy=-0.38596914166889745 vz=-0.011484808827350984>
# <rebound.particle.Particle object at 0x7fa9eb3efac0, m=1e-29 x=132472.33627517067 y=82764.79204757708 z=1733.9451847628775 vx=0.18446913178396457 vy=0.11529940550068014 vz=0.002409802890527247>
# ---------------------------------
